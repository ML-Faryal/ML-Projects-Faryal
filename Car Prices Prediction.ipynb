# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv("carprices.csv")
df.head()
# Out:
#    mileage  age   sell
# 0    69000    6  18000
# 1    35000    3  34000
# 2    57000    5  26100
# 3    22500    2  40000
# 4    46000    4  31500

# %%
x1 = df.mileage
x2 = df.age
y = df.sell

# %%
plt.figure(figsize = (5,3))
plt.xlabel('Mileage')
plt.ylabel('Sell')
plt.scatter(x1,y,marker = '+')

# %%
plt.figure(figsize = (5,3))
plt.xlabel('Age')
plt.ylabel('Sell')
plt.scatter(x2,y,marker = '*')

# %%
X = df.drop ('sell',axis = 'columns')
X.head()
# Out:
#    mileage  age
# 0    69000    6
# 1    35000    3
# 2    57000    5
# 3    22500    2
# 4    46000    4

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,
                                                 test_size = 0.3,
                                                 random_state = 50)

# %%
X_train
# Out:
#     mileage  age
# 7     72000    6
# 2     57000    5
# 17    69000    5
# 10    83000    7
# 12    59000    5
# 5     59000    5
# 6     52000    5
# 4     46000    4
# 14    82450    7
# 1     35000    3
# 13    58780    4
# 11    79000    7
# 0     69000    6
# 16    28000    2

# %%
X_test
# Out:
#     mileage  age
# 15    25400    3
# 8     91000    8
# 9     67000    6
# 18    87600    8
# 3     22500    2
# 19    52000    5

# %%
y_train
# Out:
# 7     19300
# 2     26100
# 17    19700
# 10    18700
# 12    26000
# 5     26750
# 6     32000
# 4     31500
# 14    19400
# 1     34000
# 13    27500
# 11    19500
# 0     18000
# 16    35500
# Name: sell, dtype: int64

# %%
y_test
# Out:
# 15    35000
# 8     12000
# 9     22000
# 18    12800
# 3     40000
# 19    28200
# Name: sell, dtype: int64

# %%
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 14
# 6
# 14
# 6

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.9326112096736872

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([39017.77301348, 15034.52685352, 23574.71857785, 16632.99244051,
#        39009.62274577, 29255.22525205])
